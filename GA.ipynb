# %% [markdown]
# ## Genetic Algorithm

# %% [markdown]
# The algorithm uses analogs of a genetic representation (bitstrings), fitness (function evaluations), genetic recombination (crossover of bitstrings), and mutation (flipping bits).

# %%
import numpy as np
import pandas as pd
from random import randint

# %% [markdown]
# #### Helper Functions

# %%
def binary_array_to_int(bin_array):
  length = len(bin_array)
  result = 0
  for i in range(length):
    result += 2**(length - i -1)*bin_array[i]
  return result

def int_to_binarry_array(integer, array_length):
  result = []
  for i in range(array_length):
    result.append(integer %2)
    integer = int(integer/2)
  result.reverse()
  return result


def sort_and_nomalize_individuals_scores(individuals_scores, log_mode):
  # sort individuals based on their score and sort them in the descending order
  sorted_individuals_scores = sorted(individuals_scores, key=lambda x: x[0])[::-1]
  raw_scores = [i[0] for i in sorted_individuals_scores]

  moved_scores = [i + 2*abs(min(raw_scores)) for i in raw_scores]
  normalized_scores = [round(i /sum(moved_scores), 2) for i in moved_scores]
  
  #print('raw sorted scores: ', raw_scores)
  #print('normalized sorted scores: ', normalized_scores)
  sort_and_nomalize_individuals_scores = []
  
  for i in range(len(normalized_scores)):
    sort_and_nomalize_individuals_scores.append((normalized_scores[i] , sorted_individuals_scores[i][1]))
  log(f'individuals and their normalized fitness scores, sorted by scores: {sort_and_nomalize_individuals_scores}', log_mode)
  return sort_and_nomalize_individuals_scores

def log(string, log_mode):
  if log_mode:
    print(string)

# %% [markdown]
# #### Getting Inputs

# %%
indiv_length = 5 # because it should be between 0 and 30, which is 2^5
n_population = int(input('Enter the population number: '))
mutat_probability = float(input('Enter mutation probability: '))
comb_probability = float(input('Enter combination probability: '))
comb_type = int(input('Enter combination type, 1 for one-point and 2 for uniform: '))
max_loop_iter = int(input('Enter maximum number of loop iteration: '))
log_mode = True

print(f'inputs are: indiv_length:{indiv_length}, n_population:{n_population}, mutat_probability:{mutat_probability}, comb_probability:{comb_probability}, comb_type:{comb_type}, max_loop_iter:{max_loop_iter}')
# Out:
# inputs are: indiv_length:5, n_population:4, mutat_probability:0.7, comb_probability:0.6, comb_type:1, max_loop_iter:100

# %% [markdown]
# #### Initialize the Population

# %%
def initialize_populatoin(indiv_length, n_population, log_mode):
  population = [np.random.randint(0, 2, indiv_length) for _ in range(n_population)]
  log(f'initial population: {population}', log_mode)
  return population

# %% [markdown]
# #### Fitness Function

# %%
def fitness(individual):
  individual_integer_form = binary_array_to_int(individual)
  # -x^2 + 6x
  score = - individual_integer_form**2 + 6*individual_integer_form
  return score

# %% [markdown]
# #### Parent Selection

# %%
def roulette_wheel_selection(population, log_mode):
  cumulative_propapilities = []
  for i in range(len(population)):
    #print('individual: ', population[i])
    if i ==0:
      cumulative_propapilities.append(population[i][0])
    else:
      cumulative_propapilities.append(round(population[i][0] + cumulative_propapilities[i-1], 2))
  cumulative_propapilities[len(cumulative_propapilities)-1] = 1.0
  log(f'roulette wheel(cumulative_propapilities): {cumulative_propapilities}', log_mode)

  # roulette wheel 
  parents = []
  for _ in range(len(population)):
    random_num = np.random.random()
    for i in range(len(cumulative_propapilities)):
      if random_num < cumulative_propapilities[i]:
        parents.append(population[i][1])
        break
  log(f'parents of new population: {parents}', log_mode)
  return parents

# %% [markdown]
# #### Crossover

# %%
def crossover(parents, indiv_length, comb_probability, comb_type, log_mode):
  log('combination...', log_mode)
  crossover_result = []

  #select pairs
  for i in range(int(len(parents)/2)):
    random_comb = np.random.random()
    if(random_comb < comb_probability):
      # add tolist() because chromosomes are of np.array form 
      parent1 = parents[i].tolist()
      parent2 = parents[len(parents)-1 -i].tolist()
      # 1-point crossover
      if comb_type == 1:  
        random_index = np.random.randint(1, indiv_length-1)
        child1 = np.array(parent1[:random_index]+parent2[random_index:])
        child2 = np.array(parent2[:random_index]+parent1[random_index:])
        crossover_result.append(child1)
        crossover_result.append(child2)
        log(f'random index is: {random_index}', log_mode)
        log(f'parent1: {parent1[:random_index]}{parent1[random_index:]}', log_mode)
        log(f'parent2: {parent2[:random_index]}{parent2[random_index:]}', log_mode)
        log(f'child1: {parent1[:random_index]+parent2[random_index:]}', log_mode)
        log(f'child2: {parent2[:random_index]+parent1[random_index:]}', log_mode)

      # uniform crossover
      elif comb_type==2: 
        parent1 = parents[i].tolist()
        parent2 = parents[len(parents)-1 -i].tolist()
        child1 = []
        child2 = []
        for j in range(indiv_length):
          random_result = np.random.random()
          if random_result <.5:
            child1.append(parent1[j])
            child2.append(parent2[j])
          else:
            child1.append(parent2[j])
            child2.append(parent1[j])
          
        crossover_result.append(np.array(child1))
        crossover_result.append(np.array(child2))
        log(f'parent1: {parent1}', log_mode)
        log(f'parent2: {parent2}', log_mode)
        log(f'child1: {child1}', log_mode)
        log(f'child2: {child2}', log_mode)


    else:
      crossover_result.append(parents[i])
      crossover_result.append(parents[len(parents)-1-i])
      log(f'not perfom crossover for the {i}th pair or chromosomes because the outcome of random is {round(random_comb)}, where as combination probability is: {comb_probability}', log_mode)
      log(f'child1: {parents[i].tolist()} (sam as parent)', log_mode)
      log(f'child1: {parents[len(parents)-1 -i].tolist()} (same as parent)', log_mode)
  return crossover_result

# %% [markdown]
# #### Mutation

# %%
def mutation(parents, indiv_length, mutat_probability, log_mode):
  log('mutation...', log)
  mutation_result = []
  #select pairs
  for i in range(int(len(parents))):
    parent = parents[i].tolist()
    child = []
    for j in range(indiv_length):
      random_result = np.random.random()
      #print(f'random is: {round(random_result, 2)} and mutation probability is: {mutat_probability}')
      if random_result < mutat_probability:
        # mutation happens for gene #j
        child.append(1-parent[j])
      else:
        child.append(parent[j])
    mutation_result.append(np.array(child))
    log(f'parent: {parent}', log_mode)
    log(f'child: {child}', log_mode)

  return mutation_result

# %% [markdown]
# #### Genetic Algorithm

# %%
def GA(indiv_length, n_population, mutat_probability, comb_probability, comb_type, max_loop_iter, log_mode):
  population = initialize_populatoin(indiv_length, n_population, log_mode)
  best_score = -100000
  fittest_individual = None
  for _ in range(max_loop_iter):
    log(f'population of gen#{_}: {population}', log_mode)
    individuals_scores = []
    for individual in population:
      score = fitness(individual)
      if score > best_score:
        best_score, fittest_individual= score, individual
      individuals_scores.append((score, individual))
    sorted_and_nomalized_individuals_scores = sort_and_nomalize_individuals_scores(individuals_scores, log_mode)
    #selection
    parents = roulette_wheel_selection(sorted_and_nomalized_individuals_scores, log_mode)
    #crossover
    crossover_result = crossover(parents, indiv_length, comb_probability, comb_type, log_mode)
    #mutation
    mutation_result = mutation(crossover_result, indiv_length, mutat_probability, log_mode)
  
    population = mutation_result
    
  
  log(f'fittest individual is: {binary_array_to_int(fittest_individual)}, binarry representation: {fittest_individual.tolist()}, wih score: {best_score}', log_mode)

GA(indiv_length, n_population, mutat_probability, comb_probability, comb_type, max_loop_iter, log_mode)
# Out:
# initial population: [array([1, 1, 1, 1, 1]), array([1, 0, 1, 1, 0]), array([0, 0, 0, 1, 1]), array([0, 0, 0, 0, 0])]
# population of gen#0: [array([1, 1, 1, 1, 1]), array([1, 0, 1, 1, 0]), array([0, 0, 0, 1, 1]), array([0, 0, 0, 0, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.31, array([0, 0, 0, 1, 1])), (0.3, array([0, 0, 0, 0, 0])), (0.24, array([1, 0, 1, 1, 0])), (0.15, array([1, 1, 1, 1, 1]))]
# roulette wheel(cumulative_propapilities): [0.31, 0.61, 0.85, 1.0]
# parents of new population: [array([1, 1, 1, 1, 1]), array([1, 0, 1, 1, 0]), array([0, 0, 0, 1, 1]), array([0, 0, 0, 1, 1])]
# combination...
# random index is: 3
# parent1: [1, 1, 1][1, 1]
# parent2: [0, 0, 0][1, 1]
# child1: [1, 1, 1, 1, 1]
# child2: [0, 0, 0, 1, 1]
# random index is: 1
# parent1: [1][0, 1, 1, 0]
# parent2: [0][0, 0, 1, 1]
# child1: [1, 0, 0, 1, 1]
# child2: [0, 0, 1, 1, 0]
# mutation...
# parent: [1, 1, 1, 1, 1]
# child: [1, 1, 0, 1, 0]
# parent: [0, 0, 0, 1, 1]
# child: [0, 1, 0, 0, 0]
# parent: [1, 0, 0, 1, 1]
# child: [0, 0, 0, 0, 0]
# parent: [0, 0, 1, 1, 0]
# child: [1, 1, 0, 0, 0]
# population of gen#1: [array([1, 1, 0, 1, 0]), array([0, 1, 0, 0, 0]), array([0, 0, 0, 0, 0]), array([1, 1, 0, 0, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.33, array([0, 0, 0, 0, 0])), (0.32, array([0, 1, 0, 0, 0])), (0.19, array([1, 1, 0, 0, 0])), (0.16, array([1, 1, 0, 1, 0]))]
# roulette wheel(cumulative_propapilities): [0.33, 0.65, 0.84, 1.0]
# parents of new population: [array([0, 1, 0, 0, 0]), array([0, 0, 0, 0, 0]), array([0, 0, 0, 0, 0]), array([0, 0, 0, 0, 0])]
# combination...
# not perfom crossover for the 0th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [0, 1, 0, 0, 0] (sam as parent)
# child1: [0, 0, 0, 0, 0] (same as parent)
# not perfom crossover for the 1th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [0, 0, 0, 0, 0] (sam as parent)
# child1: [0, 0, 0, 0, 0] (same as parent)
# mutation...
# parent: [0, 1, 0, 0, 0]
# child: [0, 0, 1, 0, 1]
# parent: [0, 0, 0, 0, 0]
# child: [1, 0, 0, 1, 0]
# parent: [0, 0, 0, 0, 0]
# child: [1, 0, 1, 0, 1]
# parent: [0, 0, 0, 0, 0]
# child: [1, 1, 1, 1, 1]
# population of gen#2: [array([0, 0, 1, 0, 1]), array([1, 0, 0, 1, 0]), array([1, 0, 1, 0, 1]), array([1, 1, 1, 1, 1])]
# individuals and their normalized fitness scores, sorted by scores: [(0.32, array([0, 0, 1, 0, 1])), (0.27, array([1, 0, 0, 1, 0])), (0.25, array([1, 0, 1, 0, 1])), (0.16, array([1, 1, 1, 1, 1]))]
# roulette wheel(cumulative_propapilities): [0.32, 0.59, 0.84, 1.0]
# parents of new population: [array([1, 0, 0, 1, 0]), array([1, 0, 1, 0, 1]), array([1, 1, 1, 1, 1]), array([0, 0, 1, 0, 1])]
# combination...
# not perfom crossover for the 0th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [1, 0, 0, 1, 0] (sam as parent)
# child1: [0, 0, 1, 0, 1] (same as parent)
# random index is: 3
# parent1: [1, 0, 1][0, 1]
# parent2: [1, 1, 1][1, 1]
# child1: [1, 0, 1, 1, 1]
# child2: [1, 1, 1, 0, 1]
# mutation...
# parent: [1, 0, 0, 1, 0]
# child: [0, 0, 1, 0, 1]
# parent: [0, 0, 1, 0, 1]
# child: [0, 1, 0, 1, 1]
# parent: [1, 0, 1, 1, 1]
# child: [0, 1, 0, 0, 0]
# parent: [1, 1, 1, 0, 1]
# child: [0, 0, 0, 1, 0]
# population of gen#3: [array([0, 0, 1, 0, 1]), array([0, 1, 0, 1, 1]), array([0, 1, 0, 0, 0]), array([0, 0, 0, 1, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.31, array([0, 0, 0, 1, 0])), (0.3, array([0, 0, 1, 0, 1])), (0.25, array([0, 1, 0, 0, 0])), (0.14, array([0, 1, 0, 1, 1]))]
# roulette wheel(cumulative_propapilities): [0.31, 0.61, 0.86, 1.0]
# parents of new population: [array([0, 1, 0, 0, 0]), array([0, 1, 0, 1, 1]), array([0, 0, 1, 0, 1]), array([0, 1, 0, 0, 0])]
# combination...
# random index is: 3
# parent1: [0, 1, 0][0, 0]
# parent2: [0, 1, 0][0, 0]
# child1: [0, 1, 0, 0, 0]
# child2: [0, 1, 0, 0, 0]
# not perfom crossover for the 1th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [0, 1, 0, 1, 1] (sam as parent)
# child1: [0, 0, 1, 0, 1] (same as parent)
# mutation...
# parent: [0, 1, 0, 0, 0]
# child: [1, 1, 0, 1, 1]
# parent: [0, 1, 0, 0, 0]
# child: [0, 1, 1, 0, 1]
# parent: [0, 1, 0, 1, 1]
# child: [0, 1, 0, 0, 1]
# parent: [0, 0, 1, 0, 1]
# child: [0, 1, 0, 0, 0]
# population of gen#4: [array([1, 1, 0, 1, 1]), array([0, 1, 1, 0, 1]), array([0, 1, 0, 0, 1]), array([0, 1, 0, 0, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.29, array([0, 1, 0, 0, 0])), (0.29, array([0, 1, 0, 0, 1])), (0.27, array([0, 1, 1, 0, 1])), (0.15, array([1, 1, 0, 1, 1]))]
# roulette wheel(cumulative_propapilities): [0.29, 0.58, 0.85, 1.0]
# parents of new population: [array([1, 1, 0, 1, 1]), array([0, 1, 0, 0, 1]), array([0, 1, 0, 0, 0]), array([0, 1, 0, 0, 0])]
# combination...
# not perfom crossover for the 0th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [1, 1, 0, 1, 1] (sam as parent)
# child1: [0, 1, 0, 0, 0] (same as parent)
# random index is: 2
# parent1: [0, 1][0, 0, 1]
# parent2: [0, 1][0, 0, 0]
# child1: [0, 1, 0, 0, 0]
# child2: [0, 1, 0, 0, 1]
# mutation...
# parent: [1, 1, 0, 1, 1]
# child: [1, 1, 1, 1, 1]
# parent: [0, 1, 0, 0, 0]
# child: [1, 1, 1, 1, 1]
# parent: [0, 1, 0, 0, 0]
# child: [1, 0, 1, 1, 0]
# parent: [0, 1, 0, 0, 1]
# child: [1, 0, 1, 1, 1]
# population of gen#5: [array([1, 1, 1, 1, 1]), array([1, 1, 1, 1, 1]), array([1, 0, 1, 1, 0]), array([1, 0, 1, 1, 1])]
# individuals and their normalized fitness scores, sorted by scores: [(0.31, array([1, 0, 1, 1, 0])), (0.3, array([1, 0, 1, 1, 1])), (0.2, array([1, 1, 1, 1, 1])), (0.2, array([1, 1, 1, 1, 1]))]
# roulette wheel(cumulative_propapilities): [0.31, 0.61, 0.81, 1.0]
# parents of new population: [array([1, 0, 1, 1, 0]), array([1, 0, 1, 1, 0]), array([1, 1, 1, 1, 1]), array([1, 0, 1, 1, 1])]
# combination...
# random index is: 2
# parent1: [1, 0][1, 1, 0]
# parent2: [1, 0][1, 1, 1]
# child1: [1, 0, 1, 1, 1]
# child2: [1, 0, 1, 1, 0]
# random index is: 3
# parent1: [1, 0, 1][1, 0]
# parent2: [1, 1, 1][1, 1]
# child1: [1, 0, 1, 1, 1]
# child2: [1, 1, 1, 1, 0]
# mutation...
# parent: [1, 0, 1, 1, 1]
# child: [1, 1, 0, 0, 1]
# parent: [1, 0, 1, 1, 0]
# child: [0, 1, 0, 1, 1]
# parent: [1, 0, 1, 1, 1]
# child: [0, 0, 0, 0, 1]
# parent: [1, 1, 1, 1, 0]
# child: [0, 1, 0, 0, 1]
# population of gen#6: [array([1, 1, 0, 0, 1]), array([0, 1, 0, 1, 1]), array([0, 0, 0, 0, 1]), array([0, 1, 0, 0, 1])]
# individuals and their normalized fitness scores, sorted by scores: [(0.29, array([0, 0, 0, 0, 1])), (0.28, array([0, 1, 0, 0, 1])), (0.28, array([0, 1, 0, 1, 1])), (0.15, array([1, 1, 0, 0, 1]))]
# roulette wheel(cumulative_propapilities): [0.29, 0.57, 0.85, 1.0]
# parents of new population: [array([0, 1, 0, 1, 1]), array([0, 1, 0, 0, 1]), array([0, 1, 0, 1, 1]), array([0, 1, 0, 1, 1])]
# combination...
# not perfom crossover for the 0th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [0, 1, 0, 1, 1] (sam as parent)
# child1: [0, 1, 0, 1, 1] (same as parent)
# random index is: 2
# parent1: [0, 1][0, 0, 1]
# parent2: [0, 1][0, 1, 1]
# child1: [0, 1, 0, 1, 1]
# child2: [0, 1, 0, 0, 1]
# mutation...
# parent: [0, 1, 0, 1, 1]
# child: [1, 0, 1, 0, 0]
# parent: [0, 1, 0, 1, 1]
# child: [1, 0, 1, 0, 1]
# parent: [0, 1, 0, 1, 1]
# child: [1, 0, 1, 0, 0]
# parent: [0, 1, 0, 0, 1]
# child: [1, 1, 0, 1, 0]
# population of gen#7: [array([1, 0, 1, 0, 0]), array([1, 0, 1, 0, 1]), array([1, 0, 1, 0, 0]), array([1, 1, 0, 1, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.27, array([1, 0, 1, 0, 0])), (0.27, array([1, 0, 1, 0, 0])), (0.26, array([1, 0, 1, 0, 1])), (0.19, array([1, 1, 0, 1, 0]))]
# roulette wheel(cumulative_propapilities): [0.27, 0.54, 0.8, 1.0]
# parents of new population: [array([1, 0, 1, 0, 1]), array([1, 0, 1, 0, 0]), array([1, 0, 1, 0, 0]), array([1, 0, 1, 0, 0])]
# combination...
# random index is: 3
# parent1: [1, 0, 1][0, 1]
# parent2: [1, 0, 1][0, 0]
# child1: [1, 0, 1, 0, 0]
# child2: [1, 0, 1, 0, 1]
# random index is: 3
# parent1: [1, 0, 1][0, 0]
# parent2: [1, 0, 1][0, 0]
# child1: [1, 0, 1, 0, 0]
# child2: [1, 0, 1, 0, 0]
# mutation...
# parent: [1, 0, 1, 0, 0]
# child: [0, 1, 0, 1, 1]
# parent: [1, 0, 1, 0, 1]
# child: [0, 0, 0, 1, 0]
# parent: [1, 0, 1, 0, 0]
# child: [0, 0, 1, 0, 1]
# parent: [1, 0, 1, 0, 0]
# child: [0, 1, 0, 0, 1]
# population of gen#8: [array([0, 1, 0, 1, 1]), array([0, 0, 0, 1, 0]), array([0, 0, 1, 0, 1]), array([0, 1, 0, 0, 1])]
# individuals and their normalized fitness scores, sorted by scores: [(0.32, array([0, 0, 0, 1, 0])), (0.31, array([0, 0, 1, 0, 1])), (0.22, array([0, 1, 0, 0, 1])), (0.15, array([0, 1, 0, 1, 1]))]
# roulette wheel(cumulative_propapilities): [0.32, 0.63, 0.85, 1.0]
# parents of new population: [array([0, 1, 0, 1, 1]), array([0, 0, 0, 1, 0]), array([0, 1, 0, 0, 1]), array([0, 1, 0, 0, 1])]
# combination...
# not perfom crossover for the 0th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [0, 1, 0, 1, 1] (sam as parent)
# child1: [0, 1, 0, 0, 1] (same as parent)
# random index is: 1
# parent1: [0][0, 0, 1, 0]
# parent2: [0][1, 0, 0, 1]
# child1: [0, 1, 0, 0, 1]
# child2: [0, 0, 0, 1, 0]
# mutation...
# parent: [0, 1, 0, 1, 1]
# child: [1, 0, 1, 1, 0]
# parent: [0, 1, 0, 0, 1]
# child: [1, 0, 0, 0, 0]
# parent: [0, 1, 0, 0, 1]
# child: [1, 0, 1, 1, 1]
# parent: [0, 0, 0, 1, 0]
# child: [0, 0, 1, 1, 1]
# population of gen#9: [array([1, 0, 1, 1, 0]), array([1, 0, 0, 0, 0]), array([1, 0, 1, 1, 1]), array([0, 0, 1, 1, 1])]
# individuals and their normalized fitness scores, sorted by scores: [(0.35, array([0, 0, 1, 1, 1])), (0.28, array([1, 0, 0, 0, 0])), (0.19, array([1, 0, 1, 1, 0])), (0.18, array([1, 0, 1, 1, 1]))]
# roulette wheel(cumulative_propapilities): [0.35, 0.63, 0.82, 1.0]
# parents of new population: [array([0, 0, 1, 1, 1]), array([1, 0, 1, 1, 1]), array([0, 0, 1, 1, 1]), array([1, 0, 0, 0, 0])]
# combination...
# random index is: 1
# parent1: [0][0, 1, 1, 1]
# parent2: [1][0, 0, 0, 0]
# child1: [0, 0, 0, 0, 0]
# child2: [1, 0, 1, 1, 1]
# not perfom crossover for the 1th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [1, 0, 1, 1, 1] (sam as parent)
# child1: [0, 0, 1, 1, 1] (same as parent)
# mutation...
# parent: [0, 0, 0, 0, 0]
# child: [0, 1, 1, 1, 0]
# parent: [1, 0, 1, 1, 1]
# child: [0, 1, 1, 0, 0]
# parent: [1, 0, 1, 1, 1]
# child: [1, 1, 0, 0, 0]
# parent: [0, 0, 1, 1, 1]
# child: [1, 1, 1, 1, 0]
# population of gen#10: [array([0, 1, 1, 1, 0]), array([0, 1, 1, 0, 0]), array([1, 1, 0, 0, 0]), array([1, 1, 1, 1, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.31, array([0, 1, 1, 0, 0])), (0.3, array([0, 1, 1, 1, 0])), (0.23, array([1, 1, 0, 0, 0])), (0.16, array([1, 1, 1, 1, 0]))]
# roulette wheel(cumulative_propapilities): [0.31, 0.61, 0.84, 1.0]
# parents of new population: [array([0, 1, 1, 1, 0]), array([1, 1, 0, 0, 0]), array([1, 1, 1, 1, 0]), array([0, 1, 1, 0, 0])]
# combination...
# random index is: 3
# parent1: [0, 1, 1][1, 0]
# parent2: [0, 1, 1][0, 0]
# child1: [0, 1, 1, 0, 0]
# child2: [0, 1, 1, 1, 0]
# not perfom crossover for the 1th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [1, 1, 0, 0, 0] (sam as parent)
# child1: [1, 1, 1, 1, 0] (same as parent)
# mutation...
# parent: [0, 1, 1, 0, 0]
# child: [1, 0, 0, 1, 1]
# parent: [0, 1, 1, 1, 0]
# child: [0, 1, 1, 1, 1]
# parent: [1, 1, 0, 0, 0]
# child: [1, 1, 0, 1, 1]
# parent: [1, 1, 1, 1, 0]
# child: [0, 0, 0, 1, 0]
# population of gen#11: [array([1, 0, 0, 1, 1]), array([0, 1, 1, 1, 1]), array([1, 1, 0, 1, 1]), array([0, 0, 0, 1, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.32, array([0, 0, 0, 1, 0])), (0.28, array([0, 1, 1, 1, 1])), (0.25, array([1, 0, 0, 1, 1])), (0.16, array([1, 1, 0, 1, 1]))]
# roulette wheel(cumulative_propapilities): [0.32, 0.6, 0.85, 1.0]
# parents of new population: [array([0, 0, 0, 1, 0]), array([0, 1, 1, 1, 1]), array([1, 0, 0, 1, 1]), array([0, 1, 1, 1, 1])]
# combination...
# random index is: 2
# parent1: [0, 0][0, 1, 0]
# parent2: [0, 1][1, 1, 1]
# child1: [0, 0, 1, 1, 1]
# child2: [0, 1, 0, 1, 0]
# random index is: 1
# parent1: [0][1, 1, 1, 1]
# parent2: [1][0, 0, 1, 1]
# child1: [0, 0, 0, 1, 1]
# child2: [1, 1, 1, 1, 1]
# mutation...
# parent: [0, 0, 1, 1, 1]
# child: [1, 1, 0, 0, 1]
# parent: [0, 1, 0, 1, 0]
# child: [0, 1, 0, 0, 1]
# parent: [0, 0, 0, 1, 1]
# child: [0, 0, 1, 0, 0]
# parent: [1, 1, 1, 1, 1]
# child: [0, 0, 1, 0, 0]
# population of gen#12: [array([1, 1, 0, 0, 1]), array([0, 1, 0, 0, 1]), array([0, 0, 1, 0, 0]), array([0, 0, 1, 0, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.29, array([0, 0, 1, 0, 0])), (0.29, array([0, 0, 1, 0, 0])), (0.28, array([0, 1, 0, 0, 1])), (0.14, array([1, 1, 0, 0, 1]))]
# roulette wheel(cumulative_propapilities): [0.29, 0.58, 0.86, 1.0]
# parents of new population: [array([0, 0, 1, 0, 0]), array([0, 0, 1, 0, 0]), array([0, 0, 1, 0, 0]), array([1, 1, 0, 0, 1])]
# combination...
# random index is: 1
# parent1: [0][0, 1, 0, 0]
# parent2: [1][1, 0, 0, 1]
# child1: [0, 1, 0, 0, 1]
# child2: [1, 0, 1, 0, 0]
# random index is: 3
# parent1: [0, 0, 1][0, 0]
# parent2: [0, 0, 1][0, 0]
# child1: [0, 0, 1, 0, 0]
# child2: [0, 0, 1, 0, 0]
# mutation...
# parent: [0, 1, 0, 0, 1]
# child: [1, 0, 1, 1, 0]
# parent: [1, 0, 1, 0, 0]
# child: [1, 1, 0, 1, 1]
# parent: [0, 0, 1, 0, 0]
# child: [1, 1, 0, 1, 1]
# parent: [0, 0, 1, 0, 0]
# child: [0, 1, 0, 1, 0]
# population of gen#13: [array([1, 0, 1, 1, 0]), array([1, 1, 0, 1, 1]), array([1, 1, 0, 1, 1]), array([0, 1, 0, 1, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.36, array([0, 1, 0, 1, 0])), (0.26, array([1, 0, 1, 1, 0])), (0.19, array([1, 1, 0, 1, 1])), (0.19, array([1, 1, 0, 1, 1]))]
# roulette wheel(cumulative_propapilities): [0.36, 0.62, 0.81, 1.0]
# parents of new population: [array([1, 0, 1, 1, 0]), array([0, 1, 0, 1, 0]), array([1, 0, 1, 1, 0]), array([1, 0, 1, 1, 0])]
# combination...
# random index is: 1
# parent1: [1][0, 1, 1, 0]
# parent2: [1][0, 1, 1, 0]
# child1: [1, 0, 1, 1, 0]
# child2: [1, 0, 1, 1, 0]
# random index is: 2
# parent1: [0, 1][0, 1, 0]
# parent2: [1, 0][1, 1, 0]
# child1: [0, 1, 1, 1, 0]
# child2: [1, 0, 0, 1, 0]
# mutation...
# parent: [1, 0, 1, 1, 0]
# child: [0, 1, 0, 0, 1]
# parent: [1, 0, 1, 1, 0]
# child: [0, 0, 1, 0, 1]
# parent: [0, 1, 1, 1, 0]
# child: [1, 0, 0, 0, 1]
# parent: [1, 0, 0, 1, 0]
# child: [1, 1, 1, 0, 0]
# population of gen#14: [array([0, 1, 0, 0, 1]), array([0, 0, 1, 0, 1]), array([1, 0, 0, 0, 1]), array([1, 1, 1, 0, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.3, array([0, 0, 1, 0, 1])), (0.29, array([0, 1, 0, 0, 1])), (0.25, array([1, 0, 0, 0, 1])), (0.15, array([1, 1, 1, 0, 0]))]
# roulette wheel(cumulative_propapilities): [0.3, 0.59, 0.84, 1.0]
# parents of new population: [array([0, 0, 1, 0, 1]), array([0, 0, 1, 0, 1]), array([1, 0, 0, 0, 1]), array([0, 1, 0, 0, 1])]
# combination...
# random index is: 1
# parent1: [0][0, 1, 0, 1]
# parent2: [0][1, 0, 0, 1]
# child1: [0, 1, 0, 0, 1]
# child2: [0, 0, 1, 0, 1]
# random index is: 1
# parent1: [0][0, 1, 0, 1]
# parent2: [1][0, 0, 0, 1]
# child1: [0, 0, 0, 0, 1]
# child2: [1, 0, 1, 0, 1]
# mutation...
# parent: [0, 1, 0, 0, 1]
# child: [0, 0, 0, 1, 1]
# parent: [0, 0, 1, 0, 1]
# child: [1, 1, 0, 1, 0]
# parent: [0, 0, 0, 0, 1]
# child: [1, 0, 1, 1, 1]
# parent: [1, 0, 1, 0, 1]
# child: [0, 1, 1, 1, 1]
# population of gen#15: [array([0, 0, 0, 1, 1]), array([1, 1, 0, 1, 0]), array([1, 0, 1, 1, 1]), array([0, 1, 1, 1, 1])]
# individuals and their normalized fitness scores, sorted by scores: [(0.34, array([0, 0, 0, 1, 1])), (0.29, array([0, 1, 1, 1, 1])), (0.21, array([1, 0, 1, 1, 1])), (0.17, array([1, 1, 0, 1, 0]))]
# roulette wheel(cumulative_propapilities): [0.34, 0.63, 0.84, 1.0]
# parents of new population: [array([1, 0, 1, 1, 1]), array([0, 1, 1, 1, 1]), array([1, 0, 1, 1, 1]), array([0, 0, 0, 1, 1])]
# combination...
# random index is: 2
# parent1: [1, 0][1, 1, 1]
# parent2: [0, 0][0, 1, 1]
# child1: [1, 0, 0, 1, 1]
# child2: [0, 0, 1, 1, 1]
# not perfom crossover for the 1th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [0, 1, 1, 1, 1] (sam as parent)
# child1: [1, 0, 1, 1, 1] (same as parent)
# mutation...
# parent: [1, 0, 0, 1, 1]
# child: [1, 1, 1, 0, 0]
# parent: [0, 0, 1, 1, 1]
# child: [1, 1, 0, 0, 0]
# parent: [0, 1, 1, 1, 1]
# child: [1, 1, 1, 0, 1]
# parent: [1, 0, 1, 1, 1]
# child: [0, 1, 0, 0, 1]
# population of gen#16: [array([1, 1, 1, 0, 0]), array([1, 1, 0, 0, 0]), array([1, 1, 1, 0, 1]), array([0, 1, 0, 0, 1])]
# individuals and their normalized fitness scores, sorted by scores: [(0.36, array([0, 1, 0, 0, 1])), (0.25, array([1, 1, 0, 0, 0])), (0.2, array([1, 1, 1, 0, 0])), (0.19, array([1, 1, 1, 0, 1]))]
# roulette wheel(cumulative_propapilities): [0.36, 0.61, 0.81, 1.0]
# parents of new population: [array([1, 1, 1, 0, 0]), array([1, 1, 1, 0, 0]), array([0, 1, 0, 0, 1]), array([0, 1, 0, 0, 1])]
# combination...
# random index is: 3
# parent1: [1, 1, 1][0, 0]
# parent2: [0, 1, 0][0, 1]
# child1: [1, 1, 1, 0, 1]
# child2: [0, 1, 0, 0, 0]
# random index is: 2
# parent1: [1, 1][1, 0, 0]
# parent2: [0, 1][0, 0, 1]
# child1: [1, 1, 0, 0, 1]
# child2: [0, 1, 1, 0, 0]
# mutation...
# parent: [1, 1, 1, 0, 1]
# child: [1, 0, 1, 1, 0]
# parent: [0, 1, 0, 0, 0]
# child: [0, 1, 1, 1, 1]
# parent: [1, 1, 0, 0, 1]
# child: [0, 1, 1, 0, 0]
# parent: [0, 1, 1, 0, 0]
# child: [1, 1, 0, 1, 1]
# population of gen#17: [array([1, 0, 1, 1, 0]), array([0, 1, 1, 1, 1]), array([0, 1, 1, 0, 0]), array([1, 1, 0, 1, 1])]
# individuals and their normalized fitness scores, sorted by scores: [(0.31, array([0, 1, 1, 0, 0])), (0.29, array([0, 1, 1, 1, 1])), (0.23, array([1, 0, 1, 1, 0])), (0.17, array([1, 1, 0, 1, 1]))]
# roulette wheel(cumulative_propapilities): [0.31, 0.6, 0.83, 1.0]
# parents of new population: [array([1, 0, 1, 1, 0]), array([0, 1, 1, 1, 1]), array([1, 1, 0, 1, 1]), array([0, 1, 1, 1, 1])]
# combination...
# random index is: 1
# parent1: [1][0, 1, 1, 0]
# parent2: [0][1, 1, 1, 1]
# child1: [1, 1, 1, 1, 1]
# child2: [0, 0, 1, 1, 0]
# not perfom crossover for the 1th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [0, 1, 1, 1, 1] (sam as parent)
# child1: [1, 1, 0, 1, 1] (same as parent)
# mutation...
# parent: [1, 1, 1, 1, 1]
# child: [0, 0, 1, 1, 0]
# parent: [0, 0, 1, 1, 0]
# child: [1, 0, 0, 1, 0]
# parent: [0, 1, 1, 1, 1]
# child: [1, 0, 0, 1, 0]
# parent: [1, 1, 0, 1, 1]
# child: [0, 0, 1, 0, 0]
# population of gen#18: [array([0, 0, 1, 1, 0]), array([1, 0, 0, 1, 0]), array([1, 0, 0, 1, 0]), array([0, 0, 1, 0, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.34, array([0, 0, 1, 0, 0])), (0.33, array([0, 0, 1, 1, 0])), (0.17, array([1, 0, 0, 1, 0])), (0.17, array([1, 0, 0, 1, 0]))]
# roulette wheel(cumulative_propapilities): [0.34, 0.67, 0.84, 1.0]
# parents of new population: [array([0, 0, 1, 1, 0]), array([0, 0, 1, 0, 0]), array([0, 0, 1, 1, 0]), array([0, 0, 1, 1, 0])]
# combination...
# not perfom crossover for the 0th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [0, 0, 1, 1, 0] (sam as parent)
# child1: [0, 0, 1, 1, 0] (same as parent)
# not perfom crossover for the 1th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [0, 0, 1, 0, 0] (sam as parent)
# child1: [0, 0, 1, 1, 0] (same as parent)
# mutation...
# parent: [0, 0, 1, 1, 0]
# child: [1, 0, 1, 0, 0]
# parent: [0, 0, 1, 1, 0]
# child: [1, 1, 0, 1, 1]
# parent: [0, 0, 1, 0, 0]
# child: [1, 0, 0, 1, 1]
# parent: [0, 0, 1, 1, 0]
# child: [1, 0, 1, 0, 1]
# population of gen#19: [array([1, 0, 1, 0, 0]), array([1, 1, 0, 1, 1]), array([1, 0, 0, 1, 1]), array([1, 0, 1, 0, 1])]
# individuals and their normalized fitness scores, sorted by scores: [(0.28, array([1, 0, 0, 1, 1])), (0.27, array([1, 0, 1, 0, 0])), (0.26, array([1, 0, 1, 0, 1])), (0.18, array([1, 1, 0, 1, 1]))]
# roulette wheel(cumulative_propapilities): [0.28, 0.55, 0.81, 1.0]
# parents of new population: [array([1, 0, 1, 0, 0]), array([1, 1, 0, 1, 1]), array([1, 0, 0, 1, 1]), array([1, 0, 1, 0, 0])]
# combination...
# random index is: 1
# parent1: [1][0, 1, 0, 0]
# parent2: [1][0, 1, 0, 0]
# child1: [1, 0, 1, 0, 0]
# child2: [1, 0, 1, 0, 0]
# not perfom crossover for the 1th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [1, 1, 0, 1, 1] (sam as parent)
# child1: [1, 0, 0, 1, 1] (same as parent)
# mutation...
# parent: [1, 0, 1, 0, 0]
# child: [0, 1, 0, 1, 1]
# parent: [1, 0, 1, 0, 0]
# child: [0, 1, 0, 1, 1]
# parent: [1, 1, 0, 1, 1]
# child: [0, 0, 0, 0, 0]
# parent: [1, 0, 0, 1, 1]
# child: [0, 1, 1, 0, 0]
# population of gen#20: [array([0, 1, 0, 1, 1]), array([0, 1, 0, 1, 1]), array([0, 0, 0, 0, 0]), array([0, 1, 1, 0, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.37, array([0, 0, 0, 0, 0])), (0.23, array([0, 1, 0, 1, 1])), (0.23, array([0, 1, 0, 1, 1])), (0.18, array([0, 1, 1, 0, 0]))]
# roulette wheel(cumulative_propapilities): [0.37, 0.6, 0.83, 1.0]
# parents of new population: [array([0, 0, 0, 0, 0]), array([0, 1, 1, 0, 0]), array([0, 1, 0, 1, 1]), array([0, 1, 1, 0, 0])]
# combination...
# random index is: 3
# parent1: [0, 0, 0][0, 0]
# parent2: [0, 1, 1][0, 0]
# child1: [0, 0, 0, 0, 0]
# child2: [0, 1, 1, 0, 0]
# not perfom crossover for the 1th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [0, 1, 1, 0, 0] (sam as parent)
# child1: [0, 1, 0, 1, 1] (same as parent)
# mutation...
# parent: [0, 0, 0, 0, 0]
# child: [1, 1, 1, 1, 1]
# parent: [0, 1, 1, 0, 0]
# child: [1, 0, 0, 1, 1]
# parent: [0, 1, 1, 0, 0]
# child: [1, 0, 0, 0, 1]
# parent: [0, 1, 0, 1, 1]
# child: [1, 0, 0, 0, 0]
# population of gen#21: [array([1, 1, 1, 1, 1]), array([1, 0, 0, 1, 1]), array([1, 0, 0, 0, 1]), array([1, 0, 0, 0, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.29, array([1, 0, 0, 0, 0])), (0.28, array([1, 0, 0, 0, 1])), (0.27, array([1, 0, 0, 1, 1])), (0.16, array([1, 1, 1, 1, 1]))]
# roulette wheel(cumulative_propapilities): [0.29, 0.57, 0.84, 1.0]
# parents of new population: [array([1, 1, 1, 1, 1]), array([1, 0, 0, 0, 1]), array([1, 0, 0, 0, 0]), array([1, 1, 1, 1, 1])]
# combination...
# random index is: 2
# parent1: [1, 1][1, 1, 1]
# parent2: [1, 1][1, 1, 1]
# child1: [1, 1, 1, 1, 1]
# child2: [1, 1, 1, 1, 1]
# not perfom crossover for the 1th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [1, 0, 0, 0, 1] (sam as parent)
# child1: [1, 0, 0, 0, 0] (same as parent)
# mutation...
# parent: [1, 1, 1, 1, 1]
# child: [1, 1, 0, 0, 0]
# parent: [1, 1, 1, 1, 1]
# child: [1, 0, 1, 1, 0]
# parent: [1, 0, 0, 0, 1]
# child: [0, 1, 1, 0, 0]
# parent: [1, 0, 0, 0, 0]
# child: [0, 1, 1, 1, 0]
# population of gen#22: [array([1, 1, 0, 0, 0]), array([1, 0, 1, 1, 0]), array([0, 1, 1, 0, 0]), array([0, 1, 1, 1, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.32, array([0, 1, 1, 0, 0])), (0.3, array([0, 1, 1, 1, 0])), (0.21, array([1, 0, 1, 1, 0])), (0.17, array([1, 1, 0, 0, 0]))]
# roulette wheel(cumulative_propapilities): [0.32, 0.62, 0.83, 1.0]
# parents of new population: [array([0, 1, 1, 0, 0]), array([0, 1, 1, 0, 0]), array([0, 1, 1, 0, 0]), array([1, 1, 0, 0, 0])]
# combination...
# not perfom crossover for the 0th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [0, 1, 1, 0, 0] (sam as parent)
# child1: [1, 1, 0, 0, 0] (same as parent)
# not perfom crossover for the 1th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [0, 1, 1, 0, 0] (sam as parent)
# child1: [0, 1, 1, 0, 0] (same as parent)
# mutation...
# parent: [0, 1, 1, 0, 0]
# child: [1, 1, 0, 0, 0]
# parent: [1, 1, 0, 0, 0]
# child: [0, 0, 1, 1, 0]
# parent: [0, 1, 1, 0, 0]
# child: [1, 1, 0, 1, 1]
# parent: [0, 1, 1, 0, 0]
# child: [1, 0, 1, 0, 1]
# population of gen#23: [array([1, 1, 0, 0, 0]), array([0, 0, 1, 1, 0]), array([1, 1, 0, 1, 1]), array([1, 0, 1, 0, 1])]
# individuals and their normalized fitness scores, sorted by scores: [(0.35, array([0, 0, 1, 1, 0])), (0.25, array([1, 0, 1, 0, 1])), (0.22, array([1, 1, 0, 0, 0])), (0.18, array([1, 1, 0, 1, 1]))]
# roulette wheel(cumulative_propapilities): [0.35, 0.6, 0.82, 1.0]
# parents of new population: [array([0, 0, 1, 1, 0]), array([1, 0, 1, 0, 1]), array([1, 1, 0, 1, 1]), array([0, 0, 1, 1, 0])]
# combination...
# not perfom crossover for the 0th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [0, 0, 1, 1, 0] (sam as parent)
# child1: [0, 0, 1, 1, 0] (same as parent)
# random index is: 1
# parent1: [1][0, 1, 0, 1]
# parent2: [1][1, 0, 1, 1]
# child1: [1, 1, 0, 1, 1]
# child2: [1, 0, 1, 0, 1]
# mutation...
# parent: [0, 0, 1, 1, 0]
# child: [1, 1, 0, 1, 1]
# parent: [0, 0, 1, 1, 0]
# child: [0, 0, 1, 1, 1]
# parent: [1, 1, 0, 1, 1]
# child: [1, 0, 0, 0, 0]
# parent: [1, 0, 1, 0, 1]
# child: [0, 0, 0, 1, 0]
# population of gen#24: [array([1, 1, 0, 1, 1]), array([0, 0, 1, 1, 1]), array([1, 0, 0, 0, 0]), array([0, 0, 0, 1, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.3, array([0, 0, 0, 1, 0])), (0.3, array([0, 0, 1, 1, 1])), (0.26, array([1, 0, 0, 0, 0])), (0.15, array([1, 1, 0, 1, 1]))]
# roulette wheel(cumulative_propapilities): [0.3, 0.6, 0.86, 1.0]
# parents of new population: [array([1, 0, 0, 0, 0]), array([1, 0, 0, 0, 0]), array([0, 0, 0, 1, 0]), array([1, 0, 0, 0, 0])]
# combination...
# random index is: 3
# parent1: [1, 0, 0][0, 0]
# parent2: [1, 0, 0][0, 0]
# child1: [1, 0, 0, 0, 0]
# child2: [1, 0, 0, 0, 0]
# not perfom crossover for the 1th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [1, 0, 0, 0, 0] (sam as parent)
# child1: [0, 0, 0, 1, 0] (same as parent)
# mutation...
# parent: [1, 0, 0, 0, 0]
# child: [1, 0, 1, 1, 1]
# parent: [1, 0, 0, 0, 0]
# child: [0, 1, 0, 0, 1]
# parent: [1, 0, 0, 0, 0]
# child: [0, 1, 0, 1, 1]
# parent: [0, 0, 0, 1, 0]
# child: [1, 1, 1, 0, 1]
# population of gen#25: [array([1, 0, 1, 1, 1]), array([0, 1, 0, 0, 1]), array([0, 1, 0, 1, 1]), array([1, 1, 1, 0, 1])]
# individuals and their normalized fitness scores, sorted by scores: [(0.31, array([0, 1, 0, 0, 1])), (0.3, array([0, 1, 0, 1, 1])), (0.22, array([1, 0, 1, 1, 1])), (0.16, array([1, 1, 1, 0, 1]))]
# roulette wheel(cumulative_propapilities): [0.31, 0.61, 0.83, 1.0]
# parents of new population: [array([1, 1, 1, 0, 1]), array([0, 1, 0, 1, 1]), array([0, 1, 0, 0, 1]), array([0, 1, 0, 0, 1])]
# combination...
# not perfom crossover for the 0th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [1, 1, 1, 0, 1] (sam as parent)
# child1: [0, 1, 0, 0, 1] (same as parent)
# random index is: 1
# parent1: [0][1, 0, 1, 1]
# parent2: [0][1, 0, 0, 1]
# child1: [0, 1, 0, 0, 1]
# child2: [0, 1, 0, 1, 1]
# mutation...
# parent: [1, 1, 1, 0, 1]
# child: [1, 0, 0, 0, 1]
# parent: [0, 1, 0, 0, 1]
# child: [1, 0, 1, 1, 0]
# parent: [0, 1, 0, 0, 1]
# child: [0, 0, 0, 0, 1]
# parent: [0, 1, 0, 1, 1]
# child: [1, 0, 1, 0, 0]
# population of gen#26: [array([1, 0, 0, 0, 1]), array([1, 0, 1, 1, 0]), array([0, 0, 0, 0, 1]), array([1, 0, 1, 0, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.35, array([0, 0, 0, 0, 1])), (0.26, array([1, 0, 0, 0, 1])), (0.21, array([1, 0, 1, 0, 0])), (0.18, array([1, 0, 1, 1, 0]))]
# roulette wheel(cumulative_propapilities): [0.35, 0.61, 0.82, 1.0]
# parents of new population: [array([1, 0, 1, 1, 0]), array([0, 0, 0, 0, 1]), array([1, 0, 0, 0, 1]), array([1, 0, 1, 1, 0])]
# combination...
# random index is: 1
# parent1: [1][0, 1, 1, 0]
# parent2: [1][0, 1, 1, 0]
# child1: [1, 0, 1, 1, 0]
# child2: [1, 0, 1, 1, 0]
# random index is: 3
# parent1: [0, 0, 0][0, 1]
# parent2: [1, 0, 0][0, 1]
# child1: [0, 0, 0, 0, 1]
# child2: [1, 0, 0, 0, 1]
# mutation...
# parent: [1, 0, 1, 1, 0]
# child: [1, 1, 1, 0, 1]
# parent: [1, 0, 1, 1, 0]
# child: [1, 0, 0, 0, 0]
# parent: [0, 0, 0, 0, 1]
# child: [0, 0, 1, 1, 0]
# parent: [1, 0, 0, 0, 1]
# child: [0, 1, 1, 1, 0]
# population of gen#27: [array([1, 1, 1, 0, 1]), array([1, 0, 0, 0, 0]), array([0, 0, 1, 1, 0]), array([0, 1, 1, 1, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.3, array([0, 0, 1, 1, 0])), (0.28, array([0, 1, 1, 1, 0])), (0.27, array([1, 0, 0, 0, 0])), (0.15, array([1, 1, 1, 0, 1]))]
# roulette wheel(cumulative_propapilities): [0.3, 0.58, 0.85, 1.0]
# parents of new population: [array([1, 0, 0, 0, 0]), array([1, 1, 1, 0, 1]), array([0, 0, 1, 1, 0]), array([0, 1, 1, 1, 0])]
# combination...
# not perfom crossover for the 0th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [1, 0, 0, 0, 0] (sam as parent)
# child1: [0, 1, 1, 1, 0] (same as parent)
# random index is: 1
# parent1: [1][1, 1, 0, 1]
# parent2: [0][0, 1, 1, 0]
# child1: [1, 0, 1, 1, 0]
# child2: [0, 1, 1, 0, 1]
# mutation...
# parent: [1, 0, 0, 0, 0]
# child: [0, 1, 1, 1, 0]
# parent: [0, 1, 1, 1, 0]
# child: [1, 0, 0, 0, 1]
# parent: [1, 0, 1, 1, 0]
# child: [0, 1, 1, 1, 1]
# parent: [0, 1, 1, 0, 1]
# child: [1, 0, 0, 1, 0]
# population of gen#28: [array([0, 1, 1, 1, 0]), array([1, 0, 0, 0, 1]), array([0, 1, 1, 1, 1]), array([1, 0, 0, 1, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.3, array([0, 1, 1, 1, 0])), (0.28, array([0, 1, 1, 1, 1])), (0.23, array([1, 0, 0, 0, 1])), (0.2, array([1, 0, 0, 1, 0]))]
# roulette wheel(cumulative_propapilities): [0.3, 0.58, 0.81, 1.0]
# parents of new population: [array([0, 1, 1, 1, 1]), array([0, 1, 1, 1, 0]), array([1, 0, 0, 0, 1]), array([0, 1, 1, 1, 1])]
# combination...
# random index is: 2
# parent1: [0, 1][1, 1, 1]
# parent2: [0, 1][1, 1, 1]
# child1: [0, 1, 1, 1, 1]
# child2: [0, 1, 1, 1, 1]
# not perfom crossover for the 1th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [0, 1, 1, 1, 0] (sam as parent)
# child1: [1, 0, 0, 0, 1] (same as parent)
# mutation...
# parent: [0, 1, 1, 1, 1]
# child: [1, 1, 1, 1, 1]
# parent: [0, 1, 1, 1, 1]
# child: [0, 0, 0, 1, 0]
# parent: [0, 1, 1, 1, 0]
# child: [1, 1, 0, 0, 1]
# parent: [1, 0, 0, 0, 1]
# child: [0, 0, 0, 1, 0]
# population of gen#29: [array([1, 1, 1, 1, 1]), array([0, 0, 0, 1, 0]), array([1, 1, 0, 0, 1]), array([0, 0, 0, 1, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.31, array([0, 0, 0, 1, 0])), (0.31, array([0, 0, 0, 1, 0])), (0.22, array([1, 1, 0, 0, 1])), (0.16, array([1, 1, 1, 1, 1]))]
# roulette wheel(cumulative_propapilities): [0.31, 0.62, 0.84, 1.0]
# parents of new population: [array([0, 0, 0, 1, 0]), array([1, 1, 0, 0, 1]), array([1, 1, 0, 0, 1]), array([0, 0, 0, 1, 0])]
# combination...
# not perfom crossover for the 0th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [0, 0, 0, 1, 0] (sam as parent)
# child1: [0, 0, 0, 1, 0] (same as parent)
# not perfom crossover for the 1th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [1, 1, 0, 0, 1] (sam as parent)
# child1: [1, 1, 0, 0, 1] (same as parent)
# mutation...
# parent: [0, 0, 0, 1, 0]
# child: [0, 0, 0, 1, 1]
# parent: [0, 0, 0, 1, 0]
# child: [1, 1, 1, 0, 1]
# parent: [1, 1, 0, 0, 1]
# child: [0, 0, 1, 1, 0]
# parent: [1, 1, 0, 0, 1]
# child: [1, 1, 1, 1, 0]
# population of gen#30: [array([0, 0, 0, 1, 1]), array([1, 1, 1, 0, 1]), array([0, 0, 1, 1, 0]), array([1, 1, 1, 1, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.33, array([0, 0, 0, 1, 1])), (0.33, array([0, 0, 1, 1, 0])), (0.18, array([1, 1, 1, 0, 1])), (0.16, array([1, 1, 1, 1, 0]))]
# roulette wheel(cumulative_propapilities): [0.33, 0.66, 0.84, 1.0]
# parents of new population: [array([0, 0, 1, 1, 0]), array([1, 1, 1, 1, 0]), array([0, 0, 1, 1, 0]), array([0, 0, 1, 1, 0])]
# combination...
# not perfom crossover for the 0th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [0, 0, 1, 1, 0] (sam as parent)
# child1: [0, 0, 1, 1, 0] (same as parent)
# not perfom crossover for the 1th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [1, 1, 1, 1, 0] (sam as parent)
# child1: [0, 0, 1, 1, 0] (same as parent)
# mutation...
# parent: [0, 0, 1, 1, 0]
# child: [1, 1, 0, 0, 0]
# parent: [0, 0, 1, 1, 0]
# child: [0, 1, 0, 1, 1]
# parent: [1, 1, 1, 1, 0]
# child: [0, 0, 0, 0, 0]
# parent: [0, 0, 1, 1, 0]
# child: [0, 0, 0, 1, 0]
# population of gen#31: [array([1, 1, 0, 0, 0]), array([0, 1, 0, 1, 1]), array([0, 0, 0, 0, 0]), array([0, 0, 0, 1, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.29, array([0, 0, 0, 1, 0])), (0.29, array([0, 0, 0, 0, 0])), (0.27, array([0, 1, 0, 1, 1])), (0.15, array([1, 1, 0, 0, 0]))]
# roulette wheel(cumulative_propapilities): [0.29, 0.58, 0.85, 1.0]
# parents of new population: [array([0, 0, 0, 1, 0]), array([1, 1, 0, 0, 0]), array([0, 0, 0, 0, 0]), array([1, 1, 0, 0, 0])]
# combination...
# not perfom crossover for the 0th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [0, 0, 0, 1, 0] (sam as parent)
# child1: [1, 1, 0, 0, 0] (same as parent)
# not perfom crossover for the 1th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [1, 1, 0, 0, 0] (sam as parent)
# child1: [0, 0, 0, 0, 0] (same as parent)
# mutation...
# parent: [0, 0, 0, 1, 0]
# child: [1, 1, 0, 0, 1]
# parent: [1, 1, 0, 0, 0]
# child: [1, 1, 1, 0, 0]
# parent: [1, 1, 0, 0, 0]
# child: [0, 0, 0, 0, 1]
# parent: [0, 0, 0, 0, 0]
# child: [1, 1, 1, 1, 1]
# population of gen#32: [array([1, 1, 0, 0, 1]), array([1, 1, 1, 0, 0]), array([0, 0, 0, 0, 1]), array([1, 1, 1, 1, 1])]
# individuals and their normalized fitness scores, sorted by scores: [(0.36, array([0, 0, 0, 0, 1])), (0.25, array([1, 1, 0, 0, 1])), (0.22, array([1, 1, 1, 0, 0])), (0.18, array([1, 1, 1, 1, 1]))]
# roulette wheel(cumulative_propapilities): [0.36, 0.61, 0.83, 1.0]
# parents of new population: [array([1, 1, 1, 1, 1]), array([1, 1, 0, 0, 1]), array([0, 0, 0, 0, 1]), array([0, 0, 0, 0, 1])]
# combination...
# random index is: 3
# parent1: [1, 1, 1][1, 1]
# parent2: [0, 0, 0][0, 1]
# child1: [1, 1, 1, 0, 1]
# child2: [0, 0, 0, 1, 1]
# random index is: 1
# parent1: [1][1, 0, 0, 1]
# parent2: [0][0, 0, 0, 1]
# child1: [1, 0, 0, 0, 1]
# child2: [0, 1, 0, 0, 1]
# mutation...
# parent: [1, 1, 1, 0, 1]
# child: [1, 0, 1, 1, 0]
# parent: [0, 0, 0, 1, 1]
# child: [0, 1, 1, 0, 0]
# parent: [1, 0, 0, 0, 1]
# child: [1, 1, 0, 1, 1]
# parent: [0, 1, 0, 0, 1]
# child: [1, 0, 0, 0, 1]
# population of gen#33: [array([1, 0, 1, 1, 0]), array([0, 1, 1, 0, 0]), array([1, 1, 0, 1, 1]), array([1, 0, 0, 0, 1])]
# individuals and their normalized fitness scores, sorted by scores: [(0.32, array([0, 1, 1, 0, 0])), (0.28, array([1, 0, 0, 0, 1])), (0.23, array([1, 0, 1, 1, 0])), (0.17, array([1, 1, 0, 1, 1]))]
# roulette wheel(cumulative_propapilities): [0.32, 0.6, 0.83, 1.0]
# parents of new population: [array([1, 1, 0, 1, 1]), array([1, 0, 0, 0, 1]), array([1, 0, 0, 0, 1]), array([1, 0, 1, 1, 0])]
# combination...
# random index is: 3
# parent1: [1, 1, 0][1, 1]
# parent2: [1, 0, 1][1, 0]
# child1: [1, 1, 0, 1, 0]
# child2: [1, 0, 1, 1, 1]
# random index is: 1
# parent1: [1][0, 0, 0, 1]
# parent2: [1][0, 0, 0, 1]
# child1: [1, 0, 0, 0, 1]
# child2: [1, 0, 0, 0, 1]
# mutation...
# parent: [1, 1, 0, 1, 0]
# child: [0, 0, 1, 0, 0]
# parent: [1, 0, 1, 1, 1]
# child: [1, 1, 1, 0, 1]
# parent: [1, 0, 0, 0, 1]
# child: [1, 1, 1, 1, 0]
# parent: [1, 0, 0, 0, 1]
# child: [0, 0, 1, 1, 0]
# population of gen#34: [array([0, 0, 1, 0, 0]), array([1, 1, 1, 0, 1]), array([1, 1, 1, 1, 0]), array([0, 0, 1, 1, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.33, array([0, 0, 1, 0, 0])), (0.33, array([0, 0, 1, 1, 0])), (0.18, array([1, 1, 1, 0, 1])), (0.16, array([1, 1, 1, 1, 0]))]
# roulette wheel(cumulative_propapilities): [0.33, 0.66, 0.84, 1.0]
# parents of new population: [array([1, 1, 1, 0, 1]), array([1, 1, 1, 0, 1]), array([0, 0, 1, 1, 0]), array([0, 0, 1, 0, 0])]
# combination...
# random index is: 3
# parent1: [1, 1, 1][0, 1]
# parent2: [0, 0, 1][0, 0]
# child1: [1, 1, 1, 0, 0]
# child2: [0, 0, 1, 0, 1]
# not perfom crossover for the 1th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [1, 1, 1, 0, 1] (sam as parent)
# child1: [0, 0, 1, 1, 0] (same as parent)
# mutation...
# parent: [1, 1, 1, 0, 0]
# child: [0, 0, 0, 1, 0]
# parent: [0, 0, 1, 0, 1]
# child: [1, 0, 0, 0, 1]
# parent: [1, 1, 1, 0, 1]
# child: [1, 0, 0, 1, 0]
# parent: [0, 0, 1, 1, 0]
# child: [1, 0, 0, 1, 1]
# population of gen#35: [array([0, 0, 0, 1, 0]), array([1, 0, 0, 0, 1]), array([1, 0, 0, 1, 0]), array([1, 0, 0, 1, 1])]
# individuals and their normalized fitness scores, sorted by scores: [(0.38, array([0, 0, 0, 1, 0])), (0.23, array([1, 0, 0, 0, 1])), (0.21, array([1, 0, 0, 1, 0])), (0.19, array([1, 0, 0, 1, 1]))]
# roulette wheel(cumulative_propapilities): [0.38, 0.61, 0.82, 1.0]
# parents of new population: [array([1, 0, 0, 1, 0]), array([0, 0, 0, 1, 0]), array([0, 0, 0, 1, 0]), array([0, 0, 0, 1, 0])]
# combination...
# random index is: 1
# parent1: [1][0, 0, 1, 0]
# parent2: [0][0, 0, 1, 0]
# child1: [1, 0, 0, 1, 0]
# child2: [0, 0, 0, 1, 0]
# not perfom crossover for the 1th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [0, 0, 0, 1, 0] (sam as parent)
# child1: [0, 0, 0, 1, 0] (same as parent)
# mutation...
# parent: [1, 0, 0, 1, 0]
# child: [1, 0, 1, 1, 1]
# parent: [0, 0, 0, 1, 0]
# child: [1, 1, 1, 1, 1]
# parent: [0, 0, 0, 1, 0]
# child: [1, 1, 0, 0, 1]
# parent: [0, 0, 0, 1, 0]
# child: [1, 1, 0, 0, 0]
# population of gen#36: [array([1, 0, 1, 1, 1]), array([1, 1, 1, 1, 1]), array([1, 1, 0, 0, 1]), array([1, 1, 0, 0, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.28, array([1, 0, 1, 1, 1])), (0.27, array([1, 1, 0, 0, 0])), (0.26, array([1, 1, 0, 0, 1])), (0.19, array([1, 1, 1, 1, 1]))]
# roulette wheel(cumulative_propapilities): [0.28, 0.55, 0.81, 1.0]
# parents of new population: [array([1, 1, 0, 0, 1]), array([1, 1, 1, 1, 1]), array([1, 1, 0, 0, 1]), array([1, 1, 1, 1, 1])]
# combination...
# random index is: 2
# parent1: [1, 1][0, 0, 1]
# parent2: [1, 1][1, 1, 1]
# child1: [1, 1, 1, 1, 1]
# child2: [1, 1, 0, 0, 1]
# random index is: 2
# parent1: [1, 1][1, 1, 1]
# parent2: [1, 1][0, 0, 1]
# child1: [1, 1, 0, 0, 1]
# child2: [1, 1, 1, 1, 1]
# mutation...
# parent: [1, 1, 1, 1, 1]
# child: [0, 0, 0, 0, 1]
# parent: [1, 1, 0, 0, 1]
# child: [0, 0, 1, 1, 1]
# parent: [1, 1, 0, 0, 1]
# child: [0, 0, 1, 1, 0]
# parent: [1, 1, 1, 1, 1]
# child: [1, 1, 0, 0, 0]
# population of gen#37: [array([0, 0, 0, 0, 1]), array([0, 0, 1, 1, 1]), array([0, 0, 1, 1, 0]), array([1, 1, 0, 0, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.29, array([0, 0, 0, 0, 1])), (0.29, array([0, 0, 1, 1, 0])), (0.28, array([0, 0, 1, 1, 1])), (0.14, array([1, 1, 0, 0, 0]))]
# roulette wheel(cumulative_propapilities): [0.29, 0.58, 0.86, 1.0]
# parents of new population: [array([0, 0, 1, 1, 1]), array([1, 1, 0, 0, 0]), array([0, 0, 1, 1, 1]), array([0, 0, 0, 0, 1])]
# combination...
# random index is: 2
# parent1: [0, 0][1, 1, 1]
# parent2: [0, 0][0, 0, 1]
# child1: [0, 0, 0, 0, 1]
# child2: [0, 0, 1, 1, 1]
# not perfom crossover for the 1th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [1, 1, 0, 0, 0] (sam as parent)
# child1: [0, 0, 1, 1, 1] (same as parent)
# mutation...
# parent: [0, 0, 0, 0, 1]
# child: [1, 1, 0, 1, 0]
# parent: [0, 0, 1, 1, 1]
# child: [1, 0, 1, 0, 0]
# parent: [1, 1, 0, 0, 0]
# child: [0, 0, 1, 1, 1]
# parent: [0, 0, 1, 1, 1]
# child: [1, 1, 0, 1, 1]
# population of gen#38: [array([1, 1, 0, 1, 0]), array([1, 0, 1, 0, 0]), array([0, 0, 1, 1, 1]), array([1, 1, 0, 1, 1])]
# individuals and their normalized fitness scores, sorted by scores: [(0.36, array([0, 0, 1, 1, 1])), (0.27, array([1, 0, 1, 0, 0])), (0.19, array([1, 1, 0, 1, 0])), (0.18, array([1, 1, 0, 1, 1]))]
# roulette wheel(cumulative_propapilities): [0.36, 0.63, 0.82, 1.0]
# parents of new population: [array([1, 1, 0, 1, 1]), array([1, 1, 0, 1, 1]), array([0, 0, 1, 1, 1]), array([0, 0, 1, 1, 1])]
# combination...
# random index is: 1
# parent1: [1][1, 0, 1, 1]
# parent2: [0][0, 1, 1, 1]
# child1: [1, 0, 1, 1, 1]
# child2: [0, 1, 0, 1, 1]
# not perfom crossover for the 1th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [1, 1, 0, 1, 1] (sam as parent)
# child1: [0, 0, 1, 1, 1] (same as parent)
# mutation...
# parent: [1, 0, 1, 1, 1]
# child: [0, 1, 0, 0, 0]
# parent: [0, 1, 0, 1, 1]
# child: [0, 0, 1, 1, 0]
# parent: [1, 1, 0, 1, 1]
# child: [0, 0, 1, 0, 0]
# parent: [0, 0, 1, 1, 1]
# child: [0, 1, 1, 0, 0]
# population of gen#39: [array([0, 1, 0, 0, 0]), array([0, 0, 1, 1, 0]), array([0, 0, 1, 0, 0]), array([0, 1, 1, 0, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.31, array([0, 0, 1, 0, 0])), (0.29, array([0, 0, 1, 1, 0])), (0.26, array([0, 1, 0, 0, 0])), (0.15, array([0, 1, 1, 0, 0]))]
# roulette wheel(cumulative_propapilities): [0.31, 0.6, 0.86, 1.0]
# parents of new population: [array([0, 0, 1, 1, 0]), array([0, 0, 1, 1, 0]), array([0, 0, 1, 1, 0]), array([0, 1, 0, 0, 0])]
# combination...
# random index is: 1
# parent1: [0][0, 1, 1, 0]
# parent2: [0][1, 0, 0, 0]
# child1: [0, 1, 0, 0, 0]
# child2: [0, 0, 1, 1, 0]
# random index is: 1
# parent1: [0][0, 1, 1, 0]
# parent2: [0][0, 1, 1, 0]
# child1: [0, 0, 1, 1, 0]
# child2: [0, 0, 1, 1, 0]
# mutation...
# parent: [0, 1, 0, 0, 0]
# child: [0, 0, 1, 0, 0]
# parent: [0, 0, 1, 1, 0]
# child: [0, 0, 0, 1, 1]
# parent: [0, 0, 1, 1, 0]
# child: [1, 1, 0, 0, 0]
# parent: [0, 0, 1, 1, 0]
# child: [1, 1, 1, 0, 0]
# population of gen#40: [array([0, 0, 1, 0, 0]), array([0, 0, 0, 1, 1]), array([1, 1, 0, 0, 0]), array([1, 1, 1, 0, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.32, array([0, 0, 0, 1, 1])), (0.32, array([0, 0, 1, 0, 0])), (0.21, array([1, 1, 0, 0, 0])), (0.16, array([1, 1, 1, 0, 0]))]
# roulette wheel(cumulative_propapilities): [0.32, 0.64, 0.85, 1.0]
# parents of new population: [array([1, 1, 0, 0, 0]), array([0, 0, 0, 1, 1]), array([1, 1, 0, 0, 0]), array([1, 1, 1, 0, 0])]
# combination...
# random index is: 2
# parent1: [1, 1][0, 0, 0]
# parent2: [1, 1][1, 0, 0]
# child1: [1, 1, 1, 0, 0]
# child2: [1, 1, 0, 0, 0]
# random index is: 1
# parent1: [0][0, 0, 1, 1]
# parent2: [1][1, 0, 0, 0]
# child1: [0, 1, 0, 0, 0]
# child2: [1, 0, 0, 1, 1]
# mutation...
# parent: [1, 1, 1, 0, 0]
# child: [0, 0, 0, 1, 1]
# parent: [1, 1, 0, 0, 0]
# child: [0, 0, 1, 0, 1]
# parent: [0, 1, 0, 0, 0]
# child: [1, 0, 1, 0, 1]
# parent: [1, 0, 0, 1, 1]
# child: [0, 0, 0, 1, 1]
# population of gen#41: [array([0, 0, 0, 1, 1]), array([0, 0, 1, 0, 1]), array([1, 0, 1, 0, 1]), array([0, 0, 0, 1, 1])]
# individuals and their normalized fitness scores, sorted by scores: [(0.29, array([0, 0, 0, 1, 1])), (0.29, array([0, 0, 0, 1, 1])), (0.29, array([0, 0, 1, 0, 1])), (0.14, array([1, 0, 1, 0, 1]))]
# roulette wheel(cumulative_propapilities): [0.29, 0.58, 0.87, 1.0]
# parents of new population: [array([0, 0, 0, 1, 1]), array([0, 0, 0, 1, 1]), array([0, 0, 1, 0, 1]), array([0, 0, 0, 1, 1])]
# combination...
# not perfom crossover for the 0th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [0, 0, 0, 1, 1] (sam as parent)
# child1: [0, 0, 0, 1, 1] (same as parent)
# random index is: 3
# parent1: [0, 0, 0][1, 1]
# parent2: [0, 0, 1][0, 1]
# child1: [0, 0, 0, 0, 1]
# child2: [0, 0, 1, 1, 1]
# mutation...
# parent: [0, 0, 0, 1, 1]
# child: [1, 1, 1, 0, 0]
# parent: [0, 0, 0, 1, 1]
# child: [1, 1, 1, 0, 0]
# parent: [0, 0, 0, 0, 1]
# child: [1, 1, 1, 1, 0]
# parent: [0, 0, 1, 1, 1]
# child: [1, 0, 0, 1, 0]
# population of gen#42: [array([1, 1, 1, 0, 0]), array([1, 1, 1, 0, 0]), array([1, 1, 1, 1, 0]), array([1, 0, 0, 1, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.34, array([1, 0, 0, 1, 0])), (0.23, array([1, 1, 1, 0, 0])), (0.23, array([1, 1, 1, 0, 0])), (0.2, array([1, 1, 1, 1, 0]))]
# roulette wheel(cumulative_propapilities): [0.34, 0.57, 0.8, 1.0]
# parents of new population: [array([1, 1, 1, 1, 0]), array([1, 1, 1, 1, 0]), array([1, 0, 0, 1, 0]), array([1, 1, 1, 0, 0])]
# combination...
# not perfom crossover for the 0th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [1, 1, 1, 1, 0] (sam as parent)
# child1: [1, 1, 1, 0, 0] (same as parent)
# random index is: 1
# parent1: [1][1, 1, 1, 0]
# parent2: [1][0, 0, 1, 0]
# child1: [1, 0, 0, 1, 0]
# child2: [1, 1, 1, 1, 0]
# mutation...
# parent: [1, 1, 1, 1, 0]
# child: [0, 0, 0, 1, 0]
# parent: [1, 1, 1, 0, 0]
# child: [0, 1, 0, 0, 1]
# parent: [1, 0, 0, 1, 0]
# child: [0, 0, 1, 0, 1]
# parent: [1, 1, 1, 1, 0]
# child: [1, 0, 0, 1, 1]
# population of gen#43: [array([0, 0, 0, 1, 0]), array([0, 1, 0, 0, 1]), array([0, 0, 1, 0, 1]), array([1, 0, 0, 1, 1])]
# individuals and their normalized fitness scores, sorted by scores: [(0.29, array([0, 0, 0, 1, 0])), (0.29, array([0, 0, 1, 0, 1])), (0.27, array([0, 1, 0, 0, 1])), (0.14, array([1, 0, 0, 1, 1]))]
# roulette wheel(cumulative_propapilities): [0.29, 0.58, 0.85, 1.0]
# parents of new population: [array([0, 0, 1, 0, 1]), array([0, 0, 1, 0, 1]), array([0, 0, 0, 1, 0]), array([0, 0, 1, 0, 1])]
# combination...
# random index is: 3
# parent1: [0, 0, 1][0, 1]
# parent2: [0, 0, 1][0, 1]
# child1: [0, 0, 1, 0, 1]
# child2: [0, 0, 1, 0, 1]
# not perfom crossover for the 1th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [0, 0, 1, 0, 1] (sam as parent)
# child1: [0, 0, 0, 1, 0] (same as parent)
# mutation...
# parent: [0, 0, 1, 0, 1]
# child: [1, 1, 0, 1, 0]
# parent: [0, 0, 1, 0, 1]
# child: [1, 0, 1, 0, 0]
# parent: [0, 0, 1, 0, 1]
# child: [1, 1, 0, 1, 0]
# parent: [0, 0, 0, 1, 0]
# child: [1, 0, 1, 1, 1]
# population of gen#44: [array([1, 1, 0, 1, 0]), array([1, 0, 1, 0, 0]), array([1, 1, 0, 1, 0]), array([1, 0, 1, 1, 1])]
# individuals and their normalized fitness scores, sorted by scores: [(0.31, array([1, 0, 1, 0, 0])), (0.27, array([1, 0, 1, 1, 1])), (0.21, array([1, 1, 0, 1, 0])), (0.21, array([1, 1, 0, 1, 0]))]
# roulette wheel(cumulative_propapilities): [0.31, 0.58, 0.79, 1.0]
# parents of new population: [array([1, 1, 0, 1, 0]), array([1, 1, 0, 1, 0]), array([1, 1, 0, 1, 0]), array([1, 0, 1, 0, 0])]
# combination...
# random index is: 2
# parent1: [1, 1][0, 1, 0]
# parent2: [1, 0][1, 0, 0]
# child1: [1, 1, 1, 0, 0]
# child2: [1, 0, 0, 1, 0]
# random index is: 3
# parent1: [1, 1, 0][1, 0]
# parent2: [1, 1, 0][1, 0]
# child1: [1, 1, 0, 1, 0]
# child2: [1, 1, 0, 1, 0]
# mutation...
# parent: [1, 1, 1, 0, 0]
# child: [0, 0, 0, 0, 1]
# parent: [1, 0, 0, 1, 0]
# child: [1, 1, 1, 0, 1]
# parent: [1, 1, 0, 1, 0]
# child: [0, 1, 1, 1, 0]
# parent: [1, 1, 0, 1, 0]
# child: [1, 0, 1, 0, 1]
# population of gen#45: [array([0, 0, 0, 0, 1]), array([1, 1, 1, 0, 1]), array([0, 1, 1, 1, 0]), array([1, 0, 1, 0, 1])]
# individuals and their normalized fitness scores, sorted by scores: [(0.32, array([0, 0, 0, 0, 1])), (0.29, array([0, 1, 1, 1, 0])), (0.24, array([1, 0, 1, 0, 1])), (0.16, array([1, 1, 1, 0, 1]))]
# roulette wheel(cumulative_propapilities): [0.32, 0.61, 0.85, 1.0]
# parents of new population: [array([1, 0, 1, 0, 1]), array([0, 0, 0, 0, 1]), array([1, 1, 1, 0, 1]), array([1, 0, 1, 0, 1])]
# combination...
# random index is: 3
# parent1: [1, 0, 1][0, 1]
# parent2: [1, 0, 1][0, 1]
# child1: [1, 0, 1, 0, 1]
# child2: [1, 0, 1, 0, 1]
# not perfom crossover for the 1th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [0, 0, 0, 0, 1] (sam as parent)
# child1: [1, 1, 1, 0, 1] (same as parent)
# mutation...
# parent: [1, 0, 1, 0, 1]
# child: [0, 1, 0, 1, 0]
# parent: [1, 0, 1, 0, 1]
# child: [1, 1, 0, 0, 1]
# parent: [0, 0, 0, 0, 1]
# child: [1, 1, 1, 1, 1]
# parent: [1, 1, 1, 0, 1]
# child: [0, 1, 1, 1, 0]
# population of gen#46: [array([0, 1, 0, 1, 0]), array([1, 1, 0, 0, 1]), array([1, 1, 1, 1, 1]), array([0, 1, 1, 1, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.31, array([0, 1, 0, 1, 0])), (0.3, array([0, 1, 1, 1, 0])), (0.22, array([1, 1, 0, 0, 1])), (0.16, array([1, 1, 1, 1, 1]))]
# roulette wheel(cumulative_propapilities): [0.31, 0.61, 0.83, 1.0]
# parents of new population: [array([0, 1, 0, 1, 0]), array([1, 1, 0, 0, 1]), array([0, 1, 0, 1, 0]), array([1, 1, 1, 1, 1])]
# combination...
# ...
# roulette wheel(cumulative_propapilities): [0.3, 0.59, 0.85, 1.0]
# parents of new population: [array([0, 1, 1, 0, 0]), array([0, 1, 0, 0, 1]), array([1, 0, 1, 0, 1]), array([0, 1, 0, 0, 1])]
# combination...
# random index is: 3
# parent1: [0, 1, 1][0, 0]
# parent2: [0, 1, 0][0, 1]
# child1: [0, 1, 1, 0, 1]
# child2: [0, 1, 0, 0, 0]
# random index is: 1
# parent1: [0][1, 0, 0, 1]
# parent2: [1][0, 1, 0, 1]
# child1: [0, 0, 1, 0, 1]
# child2: [1, 1, 0, 0, 1]
# mutation...
# parent: [0, 1, 1, 0, 1]
# child: [0, 1, 0, 0, 0]
# parent: [0, 1, 0, 0, 0]
# child: [1, 1, 1, 1, 1]
# parent: [0, 0, 1, 0, 1]
# child: [1, 1, 0, 1, 0]
# parent: [1, 1, 0, 0, 1]
# child: [0, 1, 0, 1, 0]
# population of gen#85: [array([0, 1, 0, 0, 0]), array([1, 1, 1, 1, 1]), array([1, 1, 0, 1, 0]), array([0, 1, 0, 1, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.32, array([0, 1, 0, 0, 0])), (0.31, array([0, 1, 0, 1, 0])), (0.21, array([1, 1, 0, 1, 0])), (0.16, array([1, 1, 1, 1, 1]))]
# roulette wheel(cumulative_propapilities): [0.32, 0.63, 0.84, 1.0]
# parents of new population: [array([0, 1, 0, 0, 0]), array([0, 1, 0, 1, 0]), array([0, 1, 0, 0, 0]), array([0, 1, 0, 0, 0])]
# combination...
# not perfom crossover for the 0th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [0, 1, 0, 0, 0] (sam as parent)
# child1: [0, 1, 0, 0, 0] (same as parent)
# random index is: 3
# parent1: [0, 1, 0][1, 0]
# parent2: [0, 1, 0][0, 0]
# child1: [0, 1, 0, 0, 0]
# child2: [0, 1, 0, 1, 0]
# mutation...
# parent: [0, 1, 0, 0, 0]
# child: [0, 1, 1, 1, 0]
# parent: [0, 1, 0, 0, 0]
# child: [0, 0, 0, 0, 1]
# parent: [0, 1, 0, 0, 0]
# child: [1, 0, 1, 1, 1]
# parent: [0, 1, 0, 1, 0]
# child: [1, 0, 1, 0, 0]
# population of gen#86: [array([0, 1, 1, 1, 0]), array([0, 0, 0, 0, 1]), array([1, 0, 1, 1, 1]), array([1, 0, 1, 0, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.33, array([0, 0, 0, 0, 1])), (0.29, array([0, 1, 1, 1, 0])), (0.21, array([1, 0, 1, 0, 0])), (0.17, array([1, 0, 1, 1, 1]))]
# roulette wheel(cumulative_propapilities): [0.33, 0.62, 0.83, 1.0]
# parents of new population: [array([0, 1, 1, 1, 0]), array([0, 0, 0, 0, 1]), array([0, 1, 1, 1, 0]), array([0, 0, 0, 0, 1])]
# combination...
# not perfom crossover for the 0th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [0, 1, 1, 1, 0] (sam as parent)
# child1: [0, 0, 0, 0, 1] (same as parent)
# random index is: 3
# parent1: [0, 0, 0][0, 1]
# parent2: [0, 1, 1][1, 0]
# child1: [0, 0, 0, 1, 0]
# child2: [0, 1, 1, 0, 1]
# mutation...
# parent: [0, 1, 1, 1, 0]
# child: [1, 0, 0, 0, 1]
# parent: [0, 0, 0, 0, 1]
# child: [1, 0, 1, 0, 0]
# parent: [0, 0, 0, 1, 0]
# child: [1, 1, 1, 0, 1]
# parent: [0, 1, 1, 0, 1]
# child: [1, 0, 0, 0, 0]
# population of gen#87: [array([1, 0, 0, 0, 1]), array([1, 0, 1, 0, 0]), array([1, 1, 1, 0, 1]), array([1, 0, 0, 0, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.29, array([1, 0, 0, 0, 0])), (0.28, array([1, 0, 0, 0, 1])), (0.26, array([1, 0, 1, 0, 0])), (0.17, array([1, 1, 1, 0, 1]))]
# roulette wheel(cumulative_propapilities): [0.29, 0.57, 0.83, 1.0]
# parents of new population: [array([1, 0, 0, 0, 1]), array([1, 0, 0, 0, 0]), array([1, 0, 1, 0, 0]), array([1, 0, 1, 0, 0])]
# combination...
# not perfom crossover for the 0th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [1, 0, 0, 0, 1] (sam as parent)
# child1: [1, 0, 1, 0, 0] (same as parent)
# not perfom crossover for the 1th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [1, 0, 0, 0, 0] (sam as parent)
# child1: [1, 0, 1, 0, 0] (same as parent)
# mutation...
# parent: [1, 0, 0, 0, 1]
# child: [0, 0, 1, 0, 1]
# parent: [1, 0, 1, 0, 0]
# child: [0, 1, 0, 0, 0]
# parent: [1, 0, 0, 0, 0]
# child: [0, 1, 1, 1, 0]
# parent: [1, 0, 1, 0, 0]
# child: [1, 1, 0, 0, 1]
# population of gen#88: [array([0, 0, 1, 0, 1]), array([0, 1, 0, 0, 0]), array([0, 1, 1, 1, 0]), array([1, 1, 0, 0, 1])]
# individuals and their normalized fitness scores, sorted by scores: [(0.3, array([0, 0, 1, 0, 1])), (0.29, array([0, 1, 0, 0, 0])), (0.26, array([0, 1, 1, 1, 0])), (0.15, array([1, 1, 0, 0, 1]))]
# roulette wheel(cumulative_propapilities): [0.3, 0.59, 0.85, 1.0]
# parents of new population: [array([0, 1, 0, 0, 0]), array([0, 1, 1, 1, 0]), array([0, 1, 1, 1, 0]), array([0, 0, 1, 0, 1])]
# combination...
# random index is: 3
# parent1: [0, 1, 0][0, 0]
# parent2: [0, 0, 1][0, 1]
# child1: [0, 1, 0, 0, 1]
# child2: [0, 0, 1, 0, 0]
# random index is: 3
# parent1: [0, 1, 1][1, 0]
# parent2: [0, 1, 1][1, 0]
# child1: [0, 1, 1, 1, 0]
# child2: [0, 1, 1, 1, 0]
# mutation...
# parent: [0, 1, 0, 0, 1]
# child: [0, 1, 1, 1, 0]
# parent: [0, 0, 1, 0, 0]
# child: [1, 0, 1, 1, 1]
# parent: [0, 1, 1, 1, 0]
# child: [0, 1, 0, 0, 0]
# parent: [0, 1, 1, 1, 0]
# child: [1, 0, 0, 0, 1]
# population of gen#89: [array([0, 1, 1, 1, 0]), array([1, 0, 1, 1, 1]), array([0, 1, 0, 0, 0]), array([1, 0, 0, 0, 1])]
# individuals and their normalized fitness scores, sorted by scores: [(0.32, array([0, 1, 0, 0, 0])), (0.28, array([0, 1, 1, 1, 0])), (0.25, array([1, 0, 0, 0, 1])), (0.16, array([1, 0, 1, 1, 1]))]
# roulette wheel(cumulative_propapilities): [0.32, 0.6, 0.85, 1.0]
# parents of new population: [array([1, 0, 1, 1, 1]), array([0, 1, 1, 1, 0]), array([0, 1, 0, 0, 0]), array([0, 1, 1, 1, 0])]
# combination...
# random index is: 2
# parent1: [1, 0][1, 1, 1]
# parent2: [0, 1][1, 1, 0]
# child1: [1, 0, 1, 1, 0]
# child2: [0, 1, 1, 1, 1]
# not perfom crossover for the 1th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [0, 1, 1, 1, 0] (sam as parent)
# child1: [0, 1, 0, 0, 0] (same as parent)
# mutation...
# parent: [1, 0, 1, 1, 0]
# child: [0, 1, 0, 0, 1]
# parent: [0, 1, 1, 1, 1]
# child: [1, 0, 0, 0, 0]
# parent: [0, 1, 1, 1, 0]
# child: [1, 0, 1, 0, 1]
# parent: [0, 1, 0, 0, 0]
# child: [1, 0, 1, 0, 0]
# population of gen#90: [array([0, 1, 0, 0, 1]), array([1, 0, 0, 0, 0]), array([1, 0, 1, 0, 1]), array([1, 0, 1, 0, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.35, array([0, 1, 0, 0, 1])), (0.27, array([1, 0, 0, 0, 0])), (0.2, array([1, 0, 1, 0, 0])), (0.18, array([1, 0, 1, 0, 1]))]
# roulette wheel(cumulative_propapilities): [0.35, 0.62, 0.82, 1.0]
# parents of new population: [array([1, 0, 0, 0, 0]), array([1, 0, 0, 0, 0]), array([1, 0, 1, 0, 1]), array([0, 1, 0, 0, 1])]
# combination...
# random index is: 2
# parent1: [1, 0][0, 0, 0]
# parent2: [0, 1][0, 0, 1]
# child1: [1, 0, 0, 0, 1]
# child2: [0, 1, 0, 0, 0]
# not perfom crossover for the 1th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [1, 0, 0, 0, 0] (sam as parent)
# child1: [1, 0, 1, 0, 1] (same as parent)
# mutation...
# parent: [1, 0, 0, 0, 1]
# child: [1, 1, 1, 1, 0]
# parent: [0, 1, 0, 0, 0]
# child: [0, 0, 1, 1, 1]
# parent: [1, 0, 0, 0, 0]
# child: [0, 1, 1, 1, 1]
# parent: [1, 0, 1, 0, 1]
# child: [1, 0, 0, 0, 0]
# population of gen#91: [array([1, 1, 1, 1, 0]), array([0, 0, 1, 1, 1]), array([0, 1, 1, 1, 1]), array([1, 0, 0, 0, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.3, array([0, 0, 1, 1, 1])), (0.28, array([0, 1, 1, 1, 1])), (0.27, array([1, 0, 0, 0, 0])), (0.15, array([1, 1, 1, 1, 0]))]
# roulette wheel(cumulative_propapilities): [0.3, 0.58, 0.85, 1.0]
# parents of new population: [array([0, 1, 1, 1, 1]), array([0, 1, 1, 1, 1]), array([0, 0, 1, 1, 1]), array([0, 1, 1, 1, 1])]
# combination...
# random index is: 1
# parent1: [0][1, 1, 1, 1]
# parent2: [0][1, 1, 1, 1]
# child1: [0, 1, 1, 1, 1]
# child2: [0, 1, 1, 1, 1]
# random index is: 1
# parent1: [0][1, 1, 1, 1]
# parent2: [0][0, 1, 1, 1]
# child1: [0, 0, 1, 1, 1]
# child2: [0, 1, 1, 1, 1]
# mutation...
# parent: [0, 1, 1, 1, 1]
# child: [0, 0, 0, 1, 0]
# parent: [0, 1, 1, 1, 1]
# child: [1, 0, 0, 0, 1]
# parent: [0, 0, 1, 1, 1]
# child: [1, 1, 0, 0, 1]
# parent: [0, 1, 1, 1, 1]
# child: [0, 0, 0, 1, 0]
# population of gen#92: [array([0, 0, 0, 1, 0]), array([1, 0, 0, 0, 1]), array([1, 1, 0, 0, 1]), array([0, 0, 0, 1, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.3, array([0, 0, 0, 1, 0])), (0.3, array([0, 0, 0, 1, 0])), (0.24, array([1, 0, 0, 0, 1])), (0.15, array([1, 1, 0, 0, 1]))]
# roulette wheel(cumulative_propapilities): [0.3, 0.6, 0.84, 1.0]
# parents of new population: [array([0, 0, 0, 1, 0]), array([0, 0, 0, 1, 0]), array([0, 0, 0, 1, 0]), array([1, 0, 0, 0, 1])]
# combination...
# random index is: 3
# parent1: [0, 0, 0][1, 0]
# parent2: [1, 0, 0][0, 1]
# child1: [0, 0, 0, 0, 1]
# child2: [1, 0, 0, 1, 0]
# random index is: 1
# parent1: [0][0, 0, 1, 0]
# parent2: [0][0, 0, 1, 0]
# child1: [0, 0, 0, 1, 0]
# child2: [0, 0, 0, 1, 0]
# mutation...
# parent: [0, 0, 0, 0, 1]
# child: [1, 0, 1, 0, 1]
# parent: [1, 0, 0, 1, 0]
# child: [0, 0, 1, 0, 0]
# parent: [0, 0, 0, 1, 0]
# child: [1, 0, 1, 1, 1]
# parent: [0, 0, 0, 1, 0]
# child: [1, 1, 0, 0, 1]
# population of gen#93: [array([1, 0, 1, 0, 1]), array([0, 0, 1, 0, 0]), array([1, 0, 1, 1, 1]), array([1, 1, 0, 0, 1])]
# individuals and their normalized fitness scores, sorted by scores: [(0.36, array([0, 0, 1, 0, 0])), (0.24, array([1, 0, 1, 0, 1])), (0.21, array([1, 0, 1, 1, 1])), (0.18, array([1, 1, 0, 0, 1]))]
# roulette wheel(cumulative_propapilities): [0.36, 0.6, 0.81, 1.0]
# parents of new population: [array([0, 0, 1, 0, 0]), array([1, 0, 1, 0, 1]), array([0, 0, 1, 0, 0]), array([1, 1, 0, 0, 1])]
# combination...
# not perfom crossover for the 0th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [0, 0, 1, 0, 0] (sam as parent)
# child1: [1, 1, 0, 0, 1] (same as parent)
# random index is: 3
# parent1: [1, 0, 1][0, 1]
# parent2: [0, 0, 1][0, 0]
# child1: [1, 0, 1, 0, 0]
# child2: [0, 0, 1, 0, 1]
# mutation...
# parent: [0, 0, 1, 0, 0]
# child: [1, 1, 1, 0, 1]
# parent: [1, 1, 0, 0, 1]
# child: [0, 0, 1, 1, 1]
# parent: [1, 0, 1, 0, 0]
# child: [0, 1, 0, 1, 1]
# parent: [0, 0, 1, 0, 1]
# child: [1, 1, 1, 1, 0]
# population of gen#94: [array([1, 1, 1, 0, 1]), array([0, 0, 1, 1, 1]), array([0, 1, 0, 1, 1]), array([1, 1, 1, 1, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.33, array([0, 0, 1, 1, 1])), (0.32, array([0, 1, 0, 1, 1])), (0.18, array([1, 1, 1, 0, 1])), (0.17, array([1, 1, 1, 1, 0]))]
# roulette wheel(cumulative_propapilities): [0.33, 0.65, 0.83, 1.0]
# parents of new population: [array([0, 1, 0, 1, 1]), array([0, 0, 1, 1, 1]), array([1, 1, 1, 0, 1]), array([0, 0, 1, 1, 1])]
# combination...
# random index is: 3
# parent1: [0, 1, 0][1, 1]
# parent2: [0, 0, 1][1, 1]
# child1: [0, 1, 0, 1, 1]
# child2: [0, 0, 1, 1, 1]
# random index is: 1
# parent1: [0][0, 1, 1, 1]
# parent2: [1][1, 1, 0, 1]
# child1: [0, 1, 1, 0, 1]
# child2: [1, 0, 1, 1, 1]
# mutation...
# parent: [0, 1, 0, 1, 1]
# child: [1, 0, 0, 0, 0]
# parent: [0, 0, 1, 1, 1]
# child: [1, 0, 0, 0, 1]
# parent: [0, 1, 1, 0, 1]
# child: [0, 1, 0, 0, 0]
# parent: [1, 0, 1, 1, 1]
# child: [1, 1, 0, 1, 1]
# population of gen#95: [array([1, 0, 0, 0, 0]), array([1, 0, 0, 0, 1]), array([0, 1, 0, 0, 0]), array([1, 1, 0, 1, 1])]
# individuals and their normalized fitness scores, sorted by scores: [(0.31, array([0, 1, 0, 0, 0])), (0.27, array([1, 0, 0, 0, 0])), (0.26, array([1, 0, 0, 0, 1])), (0.16, array([1, 1, 0, 1, 1]))]
# roulette wheel(cumulative_propapilities): [0.31, 0.58, 0.84, 1.0]
# parents of new population: [array([1, 0, 0, 0, 0]), array([0, 1, 0, 0, 0]), array([1, 0, 0, 0, 1]), array([0, 1, 0, 0, 0])]
# combination...
# not perfom crossover for the 0th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [1, 0, 0, 0, 0] (sam as parent)
# child1: [0, 1, 0, 0, 0] (same as parent)
# random index is: 2
# parent1: [0, 1][0, 0, 0]
# parent2: [1, 0][0, 0, 1]
# child1: [0, 1, 0, 0, 1]
# child2: [1, 0, 0, 0, 0]
# mutation...
# parent: [1, 0, 0, 0, 0]
# child: [1, 0, 1, 1, 0]
# parent: [0, 1, 0, 0, 0]
# child: [1, 1, 1, 0, 1]
# parent: [0, 1, 0, 0, 1]
# child: [0, 0, 0, 1, 1]
# parent: [1, 0, 0, 0, 0]
# child: [0, 1, 0, 1, 1]
# population of gen#96: [array([1, 0, 1, 1, 0]), array([1, 1, 1, 0, 1]), array([0, 0, 0, 1, 1]), array([0, 1, 0, 1, 1])]
# individuals and their normalized fitness scores, sorted by scores: [(0.31, array([0, 0, 0, 1, 1])), (0.3, array([0, 1, 0, 1, 1])), (0.23, array([1, 0, 1, 1, 0])), (0.16, array([1, 1, 1, 0, 1]))]
# roulette wheel(cumulative_propapilities): [0.31, 0.61, 0.84, 1.0]
# parents of new population: [array([0, 0, 0, 1, 1]), array([0, 0, 0, 1, 1]), array([1, 1, 1, 0, 1]), array([0, 1, 0, 1, 1])]
# combination...
# random index is: 1
# parent1: [0][0, 0, 1, 1]
# parent2: [0][1, 0, 1, 1]
# child1: [0, 1, 0, 1, 1]
# child2: [0, 0, 0, 1, 1]
# random index is: 1
# parent1: [0][0, 0, 1, 1]
# parent2: [1][1, 1, 0, 1]
# child1: [0, 1, 1, 0, 1]
# child2: [1, 0, 0, 1, 1]
# mutation...
# parent: [0, 1, 0, 1, 1]
# child: [1, 0, 1, 1, 0]
# parent: [0, 0, 0, 1, 1]
# child: [0, 1, 0, 0, 1]
# parent: [0, 1, 1, 0, 1]
# child: [0, 0, 0, 1, 1]
# parent: [1, 0, 0, 1, 1]
# child: [0, 1, 0, 0, 1]
# population of gen#97: [array([1, 0, 1, 1, 0]), array([0, 1, 0, 0, 1]), array([0, 0, 0, 1, 1]), array([0, 1, 0, 0, 1])]
# individuals and their normalized fitness scores, sorted by scores: [(0.29, array([0, 0, 0, 1, 1])), (0.28, array([0, 1, 0, 0, 1])), (0.28, array([0, 1, 0, 0, 1])), (0.15, array([1, 0, 1, 1, 0]))]
# roulette wheel(cumulative_propapilities): [0.29, 0.57, 0.85, 1.0]
# parents of new population: [array([1, 0, 1, 1, 0]), array([0, 1, 0, 0, 1]), array([0, 0, 0, 1, 1]), array([1, 0, 1, 1, 0])]
# combination...
# random index is: 2
# parent1: [1, 0][1, 1, 0]
# parent2: [1, 0][1, 1, 0]
# child1: [1, 0, 1, 1, 0]
# child2: [1, 0, 1, 1, 0]
# random index is: 1
# parent1: [0][1, 0, 0, 1]
# parent2: [0][0, 0, 1, 1]
# child1: [0, 0, 0, 1, 1]
# child2: [0, 1, 0, 0, 1]
# mutation...
# parent: [1, 0, 1, 1, 0]
# child: [0, 1, 0, 0, 1]
# parent: [1, 0, 1, 1, 0]
# child: [1, 0, 0, 0, 1]
# parent: [0, 0, 0, 1, 1]
# child: [1, 1, 1, 0, 0]
# parent: [0, 1, 0, 0, 1]
# child: [0, 0, 0, 1, 0]
# population of gen#98: [array([0, 1, 0, 0, 1]), array([1, 0, 0, 0, 1]), array([1, 1, 1, 0, 0]), array([0, 0, 0, 1, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.3, array([0, 0, 0, 1, 0])), (0.29, array([0, 1, 0, 0, 1])), (0.25, array([1, 0, 0, 0, 1])), (0.15, array([1, 1, 1, 0, 0]))]
# roulette wheel(cumulative_propapilities): [0.3, 0.59, 0.84, 1.0]
# parents of new population: [array([1, 0, 0, 0, 1]), array([1, 1, 1, 0, 0]), array([0, 1, 0, 0, 1]), array([1, 0, 0, 0, 1])]
# combination...
# random index is: 3
# parent1: [1, 0, 0][0, 1]
# parent2: [1, 0, 0][0, 1]
# child1: [1, 0, 0, 0, 1]
# child2: [1, 0, 0, 0, 1]
# random index is: 1
# parent1: [1][1, 1, 0, 0]
# parent2: [0][1, 0, 0, 1]
# child1: [1, 1, 0, 0, 1]
# child2: [0, 1, 1, 0, 0]
# mutation...
# parent: [1, 0, 0, 0, 1]
# child: [0, 1, 0, 0, 1]
# parent: [1, 0, 0, 0, 1]
# child: [0, 1, 0, 1, 0]
# parent: [1, 1, 0, 0, 1]
# child: [1, 0, 1, 1, 0]
# parent: [0, 1, 1, 0, 0]
# child: [0, 1, 0, 0, 0]
# population of gen#99: [array([0, 1, 0, 0, 1]), array([0, 1, 0, 1, 0]), array([1, 0, 1, 1, 0]), array([0, 1, 0, 0, 0])]
# individuals and their normalized fitness scores, sorted by scores: [(0.29, array([0, 1, 0, 0, 0])), (0.28, array([0, 1, 0, 0, 1])), (0.28, array([0, 1, 0, 1, 0])), (0.15, array([1, 0, 1, 1, 0]))]
# roulette wheel(cumulative_propapilities): [0.29, 0.57, 0.85, 1.0]
# parents of new population: [array([0, 1, 0, 1, 0]), array([0, 1, 0, 0, 1]), array([0, 1, 0, 1, 0]), array([0, 1, 0, 1, 0])]
# combination...
# random index is: 2
# parent1: [0, 1][0, 1, 0]
# parent2: [0, 1][0, 1, 0]
# child1: [0, 1, 0, 1, 0]
# child2: [0, 1, 0, 1, 0]
# not perfom crossover for the 1th pair or chromosomes because the outcome of random is 1, where as combination probability is: 0.6
# child1: [0, 1, 0, 0, 1] (sam as parent)
# child1: [0, 1, 0, 1, 0] (same as parent)
# mutation...
# parent: [0, 1, 0, 1, 0]
# child: [1, 0, 0, 0, 1]
# parent: [0, 1, 0, 1, 0]
# child: [1, 0, 1, 0, 0]
# parent: [0, 1, 0, 0, 1]
# child: [1, 0, 0, 1, 0]
# parent: [0, 1, 0, 1, 0]
# child: [1, 1, 1, 0, 0]
# fittest individual is: 3, binarry representation: [0, 0, 0, 1, 1], wih score: 9
